# %% [markdown]
#  Preparing Mexico Data
#
# Import
# The first part of any data science project is preparing your data, which means making sure its in the right place and format for you to conduct your analysis. The first step of any data preparation is importing your raw data and cleaning it.
#
# Task 1.2.1: Read these three files into three separate DataFrames named df1, df2, and df3, respectively.

# %%
import pandas  as pd

df1 = pd.read_csv("mexico_real_estate.csv")
df2 = pd.read_csv("mexico_real_estate_2.csv")
df3 = pd.read_csv("mexico_real_estate_3.csv")

# %%
print(df1.shape)
print(df1.head(10))
print(df1.dtypes)
print(df1.isnull().sum())
# Out:
# (700, 6)
#   property_type              state        lat         lon  area_m2  \
# 0         condo          Chihuahua  28.974293 -106.101605    269.7
# 1           NaN          chihuahua  28.855726 -106.089580    268.2
# 2     apartment   CIUDAD DE MEXICO  19.163374  -98.950584    108.6
# 3     Townhouse             Sonora  29.133288 -110.791352   -282.8
# 4       Terreno       QUINTANA ROO  19.717641  -88.401013     81.1
# 5           NaN            Puebla   19.832804  -98.157409     76.2
# 6           NaN            Chiapas  17.433676  -93.821787     75.1
# 7   Apartamento         nuevo leon  25.535722  -99.979541    310.0
# 8          Land  Ciudad de Mexico   20.067603  -99.145325    204.8
# 9           NaN          Veracruz   18.612036  -96.627109    145.9
#
#      price_usd
# 0          NaN
# 1    327355.13
# 2   7215680.28
# 3  18965969.11
# 4  11297383.16
# 5    120334.21
# 6    113975.81
# 7    468041.13
# 8  $121,627.07
# 9    125412.34
# property_type        str
# state                str
# lat              float64
# lon              float64
# area_m2          float64
# price_usd            str
# dtype: object
# property_type    75
# state             0
# lat              21
# lon              17
# area_m2          18
# price_usd        18
# dtype: int64

# %%
print(df3.shape)
print(df3.head(10))
print(df3.dtypes)
print(df3.isnull().sum())
# Out:
# (700, 5)
#   property_type               place_with_parent_names  \
# 0     Apartment             Mexico|Nuevo Leon|Apodaca
# 1         condo            Mexico|Jalisco|Guadalajara
# 2   Apartamento       Mexico|Baja California|Ensenada
# 3         villa           Mexico|Quintana Roo|Cozumel
# 4          land                 Mexico|Puebla|Atlixco
# 5         HOUSE      Mexico|Puebla|Puebla de Zaragoza
# 6     apartment  Mexico|Quintana Roo|Playa del Carmen
# 7         Condo                Mexico|Oaxaca|Huatulco
# 8         HOUSE              Mexico|Coahuila|Monclova
# 9         condo                Mexico|Guanajuato|Leon
#
#                                   lat-lon  area_m2    price_usd
# 0   26.272386538797807,-99.69333858664358    374.1    198546.39
# 1  21.179816414272228,-103.90928381708474    350.1    192501.01
# 2   30.75686615263983,-114.61153555826392    314.5          NaN
# 3    18.402178035272414,-88.6815511701174    292.1    338234.86
# 4    19.704376168280493,-98.6765463059634    291.3    143420.13
# 5   18.975900448784394,-97.90542890349666    365.4    129193.79
# 6    18.93073034081085,-87.88455182271785    376.7    671737.63
# 7   17.649145240898292,-96.86048246601753     49.0     23459.96
# 8     27.44369666449057,-101.197436163446    149.7    142291.93
# 9  21.191533406392164,-101.08404505385387     82.9  19833634.66
# property_type                  str
# place_with_parent_names        str
# lat-lon                        str
# area_m2                    float64
# price_usd                      str
# dtype: object
# property_type              89
# place_with_parent_names    17
# lat-lon                    25
# area_m2                    27
# price_usd                  28
# dtype: int64
